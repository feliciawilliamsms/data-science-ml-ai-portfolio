# %% [markdown]
# <a href="https://colab.research.google.com/github/EnhanceImpact/income-classifier-app/blob/main/ACS_Data_EDA_Notebook%20(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Dataset Description: PUMS 1-Year Data (U.S. Census Bureau)**
#
# #### The PUMS (Public Use Microdata Sample) dataset is a rich, person-level sample of responses collected by the U.S. Census Bureau through the American Community Survey (ACS).
#
# #### It provides anonymized individual-level data that allows researchers and analysts to explore demographic, social, economic, and housing characteristics of the U.S. population.
#
# #### This dataset is derived from a one-year sample, meaning it reflects the population characteristics of a single calendar year.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Step 1: Load the Data

# %%
import pandas as pd

# Replace with the path to your uploaded file
df = pd.read_csv("/content/ACSPUMS1Y2022_Georgia_Data.csv")
df.head()
# Out:
#    TEN  RAC1P  CIT  SCHL  BLD  HUPAC  COW  MAR  SEX  VEH  WKL  AGEP   WAGP  \
# 0    0      2    1    12    0      0    0    1    1   -1    3    48      0
# 1    0      1    1    18    0      0    0    5    1   -1    3    19      0
# 2    0      2    1    17    0      0    0    1    1   -1    3    36      0
# 3    0      2    1    17    0      0    4    5    1   -1    1    27  31300
# 4    0      1    1    22    0      0    0    3    1   -1    3    92      0
#
#    NPF  GRPIP  WKHP  ST
# 0    1      0     0  13
# 1    1      0     0  13
# 2    1      0     0  13
# 3    1      0    48  13
# 4    1      0     0  13

# %%
df.sample(5)
# Out:
#         TEN  RAC1P  CIT  SCHL  BLD  HUPAC  COW  MAR  SEX  VEH  WKL  AGEP  \
# 33375     1      9    1    16    2      4    0    1    2    2    3    73
# 101301    1      1    1    21    2      1    1    1    1    2    1    29
# 48669     2      1    1    16    2      4    0    5    2    3    3    37
# 63590     4      9    1    16    2      4    0    1    1    1    3    65
# 90791     2      1    1    22    2      4    0    1    2    2    3    76
#
#          WAGP  NPF  GRPIP  WKHP  ST
# 33375       0    2      0     0  13
# 101301  70000    4      0    40  13
# 48669       0    3      0     0  13
# 63590       0    2      0     0  13
# 90791       0    2      0     0  13

# %%
# Number of rows and columns
df.shape
# Out:
# (109349, 17)

# %% [markdown]
# # Step 2: Map Numeric Codes to Readable Categories

# %%
# =======================
# 1. Define Mapping Dictionaries
# =======================

marital_status_map = {
    1: "Married",
    2: "Widowed",
    3: "Divorced",
    4: "Separated",
    5: "Never married"
}

citizenship_map = {
    1: "Born in US",
    2: "Born in Territory",
    3: "Born abroad to US parents",
    4: "Naturalized",
    5: "Not a citizen"
}

class_of_worker_map = {
    0: "Not Applicable",
    1: "Private for-profit",
    2: "Private nonprofit",
    3: "Local government",
    4: "State government",
    5: "Self-employed"
}

sex_map = {
    1: "Male",
    2: "Female"
}

# Remap the education feature to reduce the dimensionality and sparse matrix issues that can occur for XGBOOST
# education_map = {
#     0: "N/A",
#     1: "No schooling",
#     2: "Nursery/Preschool",
#     3: "Kindergarten",
#     4: "Grade 1",
#     5: "Grade 2",
#     6: "Grade 3",
#     7: "Grade 4",
#     8: "Grade 5",
#     9: "Grade 6",
#     10: "Grade 7",
#     11: "Grade 8",
#     12: "Grade 9",
#     13: "Grade 10",
#     14: "Grade 11",
#     15: "12th grade, no diploma",
#     16: "HS diploma",
#     17: "GED",
#     18: "Some college <1yr",
#     19: "Some college >1yr",
#     20: "Associate's",
#     21: "Bachelor's",
#     22: "Master's",
#     23: "Professional degree"
# }

education_map = {
    0: "N/A",
    1: "No schooling",
    2: "Pre-K to Grade 4",
    3: "Pre-K to Grade 4",
    4: "Pre-K to Grade 4",
    5: "Pre-K to Grade 4",
    6: "Pre-K to Grade 4",
    7: "Pre-K to Grade 4",
    8: "Grade 5-8",
    9: "Grade 5-8",
    10: "Grade 5-8",
    11: "Grade 5-8",
    12: "Grade 9-12 (no diploma)",
    13: "Grade 9-12 (no diploma)",
    14: "Grade 9-12 (no diploma)",
    15: "Grade 9-12 (no diploma)",
    16: "High School Graduate",
    17: "High School Graduate",
    18: "Some College",
    19: "Some College",
    20: "Associate's",
    21: "Bachelor's",
    22: "Graduate Degree",
    23: "Graduate Degree"
}

race_map = {
    1: "White",
    2: "Black",
    3: "American Indian",
    4: "Alaska Native",
    5: "Tribes Specified",
    6: "Asian",
    7: "Pacific Islander",
    8: "Other",
    9: "Two or More Races"
}

tenure_map = {
0: "N/A",
1: "Owned with mortgage or loan (include home equity loans)",
2: "Owned Free And Clear",
3: "Rented",
4: "Occupied without payment of rent"
}

building_map = {
0: "N/A",
1: "Mobile Home or Trailer",
2: "One-family house detached",
3: "One-family house attached",
4: "2 Apartments",
5: "3-4 Apartments",
6: "5-9 Apartments",
7: "10-19 Apartments",
8: "20-49 Apartments",
9: "50 or More Apartments",
10: "Boat, RV, van, etc."
}

children_map = {
0: "N/A",
1: "With children under 6 years only",
2: "With children 6 to 17 years only",
3: "With children under 6 years and 6 to 17 years",
4: "No children"
}

vehicle_map = {
-1: "N/A",
0: "No vehicles",
1: "1 vehicle",
2: "2 vehicles",
3: "3 vehicles",
4: "4 vehicles",
5: "5 vehicles",
6: "6 or more vehicles"
}


# =======================
# 2. Apply the Mapping
# =======================

df["MAR"] = df["MAR"].map(marital_status_map)
df["CIT"] = df["CIT"].map(citizenship_map)
df["COW"] = df["COW"].map(class_of_worker_map)
df["SEX"] = df["SEX"].map(sex_map)
df["SCHL"] = df["SCHL"].map(education_map)
df["RAC1P"] = df["RAC1P"].map(race_map)
df["TEN"] = df["TEN"].map(tenure_map)
df["BLD"] = df["BLD"].map(building_map)
df["HUPAC"] = df["HUPAC"].map(children_map)
df["VEH"] = df["VEH"].map(vehicle_map)

# View the first five rows
df.head()
# Out:
#    TEN  RAC1P         CIT                     SCHL  BLD HUPAC  \
# 0  N/A  Black  Born in US  Grade 9-12 (no diploma)  N/A   N/A
# 1  N/A  White  Born in US             Some College  N/A   N/A
# 2  N/A  Black  Born in US     High School Graduate  N/A   N/A
# 3  N/A  Black  Born in US     High School Graduate  N/A   N/A
# 4  N/A  White  Born in US          Graduate Degree  N/A   N/A
#
#                 COW            MAR   SEX  VEH  WKL  AGEP   WAGP  NPF  GRPIP  \
# 0    Not Applicable        Married  Male  N/A    3    48      0    1      0
# 1    Not Applicable  Never married  Male  N/A    3    19      0    1      0
# 2    Not Applicable        Married  Male  N/A    3    36      0    1      0
# 3  State government  Never married  Male  N/A    1    27  31300    1      0
# 4    Not Applicable       Divorced  Male  N/A    3    92      0    1      0
#
#    WKHP  ST
# 0     0  13
# 1     0  13
# 2     0  13
# 3    48  13
# 4     0  13

# %%
#@title Step 3: Inspect Raw Data
print(df.info())
print(df.isnull().sum())
print("\nDuplicate rows:", df.duplicated().sum())
print(df.describe(include="all"))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109349 entries, 0 to 109348
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   TEN     109349 non-null  object
#  1   RAC1P   109349 non-null  object
#  2   CIT     109349 non-null  object
#  3   SCHL    107898 non-null  object
#  4   BLD     109349 non-null  object
#  5   HUPAC   109349 non-null  object
#  6   COW     101673 non-null  object
#  7   MAR     109349 non-null  object
#  8   SEX     109349 non-null  object
#  9   VEH     109349 non-null  object
#  10  WKL     109349 non-null  int64
#  11  AGEP    109349 non-null  int64
#  12  WAGP    109349 non-null  int64
#  13  NPF     109349 non-null  int64
#  14  GRPIP   109349 non-null  int64
#  15  WKHP    109349 non-null  int64
#  16  ST      109349 non-null  int64
# dtypes: int64(7), object(10)
# memory usage: 14.2+ MB
# None
# TEN         0
# RAC1P       0
# CIT         0
# SCHL     1451
# BLD         0
# HUPAC       0
# COW      7676
# MAR         0
# SEX         0
# VEH         0
# WKL         0
# AGEP        0
# WAGP        0
# NPF         0
# GRPIP       0
# WKHP        0
# ST          0
# dtype: int64
#
# Duplicate rows: 15842
#                                                       TEN   RAC1P         CIT  \
# count                                              109349  109349      109349
# unique                                                  5       9           5
# top     Owned with mortgage or loan (include home equi...   White  Born in US
# freq                                                50406   65529       96826
# mean                                                  NaN     NaN         NaN
# std                                                   NaN     NaN         NaN
# min                                                   NaN     NaN         NaN
# 25%                                                   NaN     NaN         NaN
# 50%                                                   NaN     NaN         NaN
# 75%                                                   NaN     NaN         NaN
# max                                                   NaN     NaN         NaN
#
#                         SCHL                        BLD        HUPAC  \
# count                 107898                     109349       109349
# unique                    10                         11            5
# top     High School Graduate  One-family house detached  No children
# freq                   24546                      79774        56098
# mean                     NaN                        NaN          NaN
# std                      NaN                        NaN          NaN
# min                      NaN                        NaN          NaN
# 25%                      NaN                        NaN          NaN
# 50%                      NaN                        NaN          NaN
# 75%                      NaN                        NaN          NaN
# max                      NaN                        NaN          NaN
#
#                    COW      MAR     SEX         VEH            WKL  \
# count           101673   109349  109349      109349  109349.000000
# unique               6        5       2           8            NaN
# top     Not Applicable  Married  Female  2 vehicles            NaN
# freq             44421    46512   56049       43439            NaN
# mean               NaN      NaN     NaN         NaN       1.379235
# std                NaN      NaN     NaN         NaN       1.026483
# min                NaN      NaN     NaN         NaN       0.000000
# 25%                NaN      NaN     NaN         NaN       1.000000
# 50%                NaN      NaN     NaN         NaN       1.000000
# 75%                NaN      NaN     NaN         NaN       2.000000
# max                NaN      NaN     NaN         NaN       3.000000
#
#                  AGEP           WAGP            NPF          GRPIP  \
# count   109349.000000  109349.000000  109349.000000  109349.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean        41.902249   28632.636567       2.963283       7.796349
# std         23.539722   58495.517030       1.672345      19.608186
# min          0.000000      -1.000000       1.000000       0.000000
# 25%         22.000000       0.000000       2.000000       0.000000
# 50%         42.000000       0.000000       3.000000       0.000000
# 75%         61.000000   40000.000000       4.000000       0.000000
# max         92.000000  539000.000000      16.000000     101.000000
#
#                  WKHP        ST
# count   109349.000000  109349.0
# unique            NaN       NaN
# top               NaN       NaN
# freq              NaN       NaN
# mean        19.772133      13.0
# std         21.438639       0.0
# min          0.000000      13.0
# 25%          0.000000      13.0
# 50%          8.000000      13.0
# 75%         40.000000      13.0
# max         99.000000      13.0

# %% [markdown]
# # Step 4: Create Income Category (`<=50K`, `>50K`)

# %%
import numpy as np

df["income"] = np.where(df["WAGP"] > 50000, ">50K", "<=50K")
df["income"].value_counts()

# View the first five rows
df.head()
# Out:
#    TEN  RAC1P         CIT                     SCHL  BLD HUPAC  \
# 0  N/A  Black  Born in US  Grade 9-12 (no diploma)  N/A   N/A
# 1  N/A  White  Born in US             Some College  N/A   N/A
# 2  N/A  Black  Born in US     High School Graduate  N/A   N/A
# 3  N/A  Black  Born in US     High School Graduate  N/A   N/A
# 4  N/A  White  Born in US          Graduate Degree  N/A   N/A
#
#                 COW            MAR   SEX  VEH  WKL  AGEP   WAGP  NPF  GRPIP  \
# 0    Not Applicable        Married  Male  N/A    3    48      0    1      0
# 1    Not Applicable  Never married  Male  N/A    3    19      0    1      0
# 2    Not Applicable        Married  Male  N/A    3    36      0    1      0
# 3  State government  Never married  Male  N/A    1    27  31300    1      0
# 4    Not Applicable       Divorced  Male  N/A    3    92      0    1      0
#
#    WKHP  ST income
# 0     0  13  <=50K
# 1     0  13  <=50K
# 2     0  13  <=50K
# 3    48  13  <=50K
# 4     0  13  <=50K

# %%
df.sample(5)
# Out:
#                                                      TEN  RAC1P  \
# 93234  Owned with mortgage or loan (include home equi...  Black
# 70312  Owned with mortgage or loan (include home equi...  White
# 85759  Owned with mortgage or loan (include home equi...  Asian
# 31730                               Owned Free And Clear  White
# 20008  Owned with mortgage or loan (include home equi...  White
#
#                  CIT                     SCHL                        BLD  \
# 93234     Born in US         Pre-K to Grade 4  One-family house detached
# 70312  Not a citizen             Some College  One-family house detached
# 85759     Born in US  Grade 9-12 (no diploma)  One-family house detached
# 31730    Naturalized             Some College  One-family house detached
# 20008     Born in US     High School Graduate  One-family house detached
#
#                                                HUPAC                 COW  \
# 93234  With children under 6 years and 6 to 17 years      Not Applicable
# 70312                                    No children    Local government
# 85759               With children 6 to 17 years only      Not Applicable
# 31730               With children 6 to 17 years only    State government
# 20008                                    No children  Private for-profit
#
#                  MAR     SEX         VEH  WKL  AGEP   WAGP  NPF  GRPIP  WKHP  \
# 93234  Never married    Male  2 vehicles    0     7     -1    5      0     0
# 70312        Married  Female  3 vehicles    1    59  10000    3      0    15
# 85759  Never married  Female  2 vehicles    0    14     -1    4      0     0
# 31730        Married  Female   1 vehicle    1    57  25000    3      0    20
# 20008  Never married  Female  2 vehicles    1    55  72000    2      0    49
#
#        ST income
# 93234  13  <=50K
# 70312  13  <=50K
# 85759  13  <=50K
# 31730  13  <=50K
# 20008  13   >50K

# %% [markdown]
# # Step 5: Drop Duplicates, Fiter the Data Remove People Under 16

# %%
# Step 1: Filter rows by age >= 16
df_filtered = df.loc[df["AGEP"] >= 16].copy()

# Step 2: Drop the 'ST' and 'WAG' columns
df_filtered = df_filtered.drop(["ST","WAGP"], axis=1)

# Step 3: Drop duplicates
df_filtered = df_filtered.drop_duplicates()

print(df_filtered.head())
print(df_filtered.info())
print(df_filtered.isnull().sum())
print("\nDuplicate rows:", df_filtered.duplicated().sum())
print(df_filtered.shape)
# Out:
#    TEN  RAC1P         CIT                     SCHL  BLD HUPAC  \
# 0  N/A  Black  Born in US  Grade 9-12 (no diploma)  N/A   N/A
# 1  N/A  White  Born in US             Some College  N/A   N/A
# 2  N/A  Black  Born in US     High School Graduate  N/A   N/A
# 3  N/A  Black  Born in US     High School Graduate  N/A   N/A
# 4  N/A  White  Born in US          Graduate Degree  N/A   N/A
#
#                 COW            MAR   SEX  VEH  WKL  AGEP  NPF  GRPIP  WKHP  \
# 0    Not Applicable        Married  Male  N/A    3    48    1      0     0
# 1    Not Applicable  Never married  Male  N/A    3    19    1      0     0
# 2    Not Applicable        Married  Male  N/A    3    36    1      0     0
# 3  State government  Never married  Male  N/A    1    27    1      0    48
# 4    Not Applicable       Divorced  Male  N/A    3    92    1      0     0
#
#   income
# 0  <=50K
# 1  <=50K
# 2  <=50K
# 3  <=50K
# 4  <=50K
# <class 'pandas.core.frame.DataFrame'>
# Index: 79905 entries, 0 to 109346
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TEN     79905 non-null  object
#  1   RAC1P   79905 non-null  object
#  2   CIT     79905 non-null  object
#  3   SCHL    78507 non-null  object
#  4   BLD     79905 non-null  object
#  5   HUPAC   79905 non-null  object
#  6   COW     72440 non-null  object
#  7   MAR     79905 non-null  object
#  8   SEX     79905 non-null  object
#  9   VEH     79905 non-null  object
#  10  WKL     79905 non-null  int64
#  11  AGEP    79905 non-null  int64
#  12  NPF     79905 non-null  int64
#  13  GRPIP   79905 non-null  int64
#  14  WKHP    79905 non-null  int64
#  15  income  79905 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 10.4+ MB
# None
# TEN          0
# RAC1P        0
# CIT          0
# SCHL      1398
# BLD          0
# HUPAC        0
# COW       7465
# MAR          0
# SEX          0
# VEH          0
# WKL          0
# AGEP         0
# NPF          0
# GRPIP        0
# WKHP         0
# income       0
# dtype: int64
#
# Duplicate rows: 0
# (79905, 16)

# %% [markdown]
# # Step 6: Impute Missing Values

# %%
# Impute SCHL based on group mode
df_filtered.loc[:, "SCHL"] = df_filtered.groupby(
    ["AGEP", "MAR"]
)["SCHL"].transform(
    lambda x: x.fillna(x.mode()[0]) if not x.mode().empty else x.fillna("Unknown")
)

print(df_filtered.isnull().sum())
# Out:
# TEN          0
# RAC1P        0
# CIT          0
# SCHL         0
# BLD          0
# HUPAC        0
# COW       7465
# MAR          0
# SEX          0
# VEH          0
# WKL          0
# AGEP         0
# NPF          0
# GRPIP        0
# WKHP         0
# income       0
# dtype: int64

# %%
# Impute SCHL based on group mode
df_filtered.loc[:, "COW"] = df_filtered.groupby(
    ["AGEP", "MAR"]
)["COW"].transform(
    lambda x: x.fillna(x.mode()[0]) if not x.mode().empty else x.fillna("Unknown")
)

print(df_filtered.isnull().sum())
# Out:
# TEN       0
# RAC1P     0
# CIT       0
# SCHL      0
# BLD       0
# HUPAC     0
# COW       0
# MAR       0
# SEX       0
# VEH       0
# WKL       0
# AGEP      0
# NPF       0
# GRPIP     0
# WKHP      0
# income    0
# dtype: int64

# %% [markdown]
# # Step 7 Summary Stats

# %%
# View summary statistics after removing minors
df_filtered.describe(include="all")
# Out:
#                                                       TEN  RAC1P         CIT  \
# count                                               79905  79905       79905
# unique                                                  5      9           5
# top     Owned with mortgage or loan (include home equi...  White  Born in US
# freq                                                36814  47468       68486
# mean                                                  NaN    NaN         NaN
# std                                                   NaN    NaN         NaN
# min                                                   NaN    NaN         NaN
# 25%                                                   NaN    NaN         NaN
# 50%                                                   NaN    NaN         NaN
# 75%                                                   NaN    NaN         NaN
# max                                                   NaN    NaN         NaN
#
#                         SCHL                        BLD        HUPAC  \
# count                  79905                      79905        79905
# unique                     9                         11            5
# top     High School Graduate  One-family house detached  No children
# freq                   21770                      58416        50435
# mean                     NaN                        NaN          NaN
# std                      NaN                        NaN          NaN
# min                      NaN                        NaN          NaN
# 25%                      NaN                        NaN          NaN
# 50%                      NaN                        NaN          NaN
# 75%                      NaN                        NaN          NaN
# max                      NaN                        NaN          NaN
#
#                        COW      MAR     SEX         VEH           WKL  \
# count                79905    79905   79905       79905  79905.000000
# unique                   6        5       2           8           NaN
# top     Private for-profit  Married  Female  2 vehicles           NaN
# freq                 45475    41049   41822       30149           NaN
# mean                   NaN      NaN     NaN         NaN      1.577899
# std                    NaN      NaN     NaN         NaN      0.850888
# min                    NaN      NaN     NaN         NaN      1.000000
# 25%                    NaN      NaN     NaN         NaN      1.000000
# 50%                    NaN      NaN     NaN         NaN      1.000000
# 75%                    NaN      NaN     NaN         NaN      2.000000
# max                    NaN      NaN     NaN         NaN      3.000000
#
#                 AGEP           NPF         GRPIP          WKHP income
# count   79905.000000  79905.000000  79905.000000  79905.000000  79905
# unique           NaN           NaN           NaN           NaN      2
# top              NaN           NaN           NaN           NaN  <=50K
# freq             NaN           NaN           NaN           NaN  60215
# mean       48.337363      2.775095      8.171253     25.650497    NaN
# std        18.606633      1.572413     19.834113     21.157347    NaN
# min        16.000000      1.000000      0.000000      0.000000    NaN
# 25%        33.000000      2.000000      0.000000      0.000000    NaN
# 50%        49.000000      2.000000      0.000000     36.000000    NaN
# 75%        63.000000      4.000000      0.000000     40.000000    NaN
# max        92.000000     16.000000    101.000000     99.000000    NaN

# %%
print(df_filtered.head())
print(df_filtered.info())
print(df_filtered.isnull().sum())
print("\nDuplicate rows:", df_filtered.duplicated().sum())
print(df_filtered.shape)
# Out:
#    TEN  RAC1P         CIT                     SCHL  BLD HUPAC  \
# 0  N/A  Black  Born in US  Grade 9-12 (no diploma)  N/A   N/A
# 1  N/A  White  Born in US             Some College  N/A   N/A
# 2  N/A  Black  Born in US     High School Graduate  N/A   N/A
# 3  N/A  Black  Born in US     High School Graduate  N/A   N/A
# 4  N/A  White  Born in US          Graduate Degree  N/A   N/A
#
#                 COW            MAR   SEX  VEH  WKL  AGEP  NPF  GRPIP  WKHP  \
# 0    Not Applicable        Married  Male  N/A    3    48    1      0     0
# 1    Not Applicable  Never married  Male  N/A    3    19    1      0     0
# 2    Not Applicable        Married  Male  N/A    3    36    1      0     0
# 3  State government  Never married  Male  N/A    1    27    1      0    48
# 4    Not Applicable       Divorced  Male  N/A    3    92    1      0     0
#
#   income
# 0  <=50K
# 1  <=50K
# 2  <=50K
# 3  <=50K
# 4  <=50K
# <class 'pandas.core.frame.DataFrame'>
# Index: 79905 entries, 0 to 109346
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TEN     79905 non-null  object
#  1   RAC1P   79905 non-null  object
#  2   CIT     79905 non-null  object
#  3   SCHL    79905 non-null  object
#  4   BLD     79905 non-null  object
#  5   HUPAC   79905 non-null  object
#  6   COW     79905 non-null  object
#  7   MAR     79905 non-null  object
#  8   SEX     79905 non-null  object
#  9   VEH     79905 non-null  object
#  10  WKL     79905 non-null  int64
#  11  AGEP    79905 non-null  int64
#  12  NPF     79905 non-null  int64
#  13  GRPIP   79905 non-null  int64
#  14  WKHP    79905 non-null  int64
#  15  income  79905 non-null  object
# dtypes: int64(5), object(11)
# memory usage: 10.4+ MB
# None
# TEN       0
# RAC1P     0
# CIT       0
# SCHL      0
# BLD       0
# HUPAC     0
# COW       0
# MAR       0
# SEX       0
# VEH       0
# WKL       0
# AGEP      0
# NPF       0
# GRPIP     0
# WKHP      0
# income    0
# dtype: int64
#
# Duplicate rows: 463
# (79905, 16)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize class imbalance
sns.countplot(data=df_filtered, x='income')
plt.title('Income Class Distribution')
plt.show()

print('Income Class Counts', (df_filtered['income'].value_counts()/df_filtered.shape[0]))
# Out:
# Income Class Counts income
# <=50K    0.753582
# >50K     0.246418
# Name: count, dtype: float64

# %%
#@title Visualize the count of income levels within categories.
import seaborn as sns
import matplotlib.pyplot as plt

categorical_vars = ['CIT','COW','MAR','SEX','SCHL','RAC1P']
for var in categorical_vars:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=df_filtered, x=var, hue='income')
    plt.title(f'Income Distribution by {var}')
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ##Crosstab + Chi-Square Test of Independence
# A p-value < 0.05 suggests a statistically significant relationship between the variable and income.

# %%
#@title To statistically test if there’s an association between the categorical variable and income.
import scipy.stats as stats

for var in categorical_vars:
    table = pd.crosstab(df_filtered[var], df_filtered['income'])
    chi2, p, dof, expected = stats.chi2_contingency(table)
    print(f'{var}: p-value = {p:.4f}')
# Out:
# CIT: p-value = 0.0000
# COW: p-value = 0.0000
# MAR: p-value = 0.0000
# SEX: p-value = 0.0000
# SCHL: p-value = 0.0000
# RAC1P: p-value = 0.0000
